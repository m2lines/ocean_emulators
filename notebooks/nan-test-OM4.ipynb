# %% [markdown]
# # OM4 nan test

# %%
from ocean_emulators.preprocessing import test_nan_consistency

# %%
import glob
import xarray as xr

directory = '/scratch/aa9537/OM4-5daily/'
files = sorted(glob.glob(f"{directory}*ocean_5daily.nc"))
# grid_path = 
# files
pick_vars = [
 # 'average_DT',
 # 'average_T1',
 # 'average_T2',
 'hfds',
 'so',
 'tauuo',
 'tauvo',
 'thetao',
 'time_bnds',
 'uo',
 'vo',
 'zos'
]

# %%
ds_raw = xr.open_mfdataset(
    files,
    use_cftime=True,
    parallel=True,
    chunks={'time':1},
    combine='nested',
    concat_dim='time',
)
ds = ds_raw[pick_vars]
ds = ds.rename({'z_l':'lev'})
ds = ds.astype('float32')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 4745, yh: 1080, xh: 1440, lev: 19, xq: 1441, yq: 1081,
#                 nv: 2)
# Coordinates:
#   * xh         (xh) float64 -299.7 -299.5 -299.2 -299.0 ... 59.53 59.78 60.03
#   * yh         (yh) float64 -80.39 -80.31 -80.23 -80.15 ... 89.73 89.84 89.95
#   * time       (time) object 1958-01-03 12:00:00 ... 2022-12-29 12:00:00
#   * nv         (nv) float64 1.0 2.0
#   * lev        (lev) float64 2.5 10.0 22.5 40.0 ... 3.1e+03 4e+03 5e+03 6e+03
#   * xq         (xq) float64 -299.8 -299.6 -299.3 -299.1 ... 59.66 59.91 60.16
#   * yq         (yq) float64 -80.43 -80.35 -80.27 -80.19 ... 89.78 89.89 90.0
# Data variables:
#     hfds       (time, yh, xh) float32 dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     so         (time, lev, yh, xh) float32 dask.array<chunksize=(1, 19, 1080, 1440), meta=np.ndarray>
#     tauuo      (time, yh, xq) float32 dask.array<chunksize=(1, 1080, 1441), meta=np.ndarray>
#     tauvo      (time, yq, xh) float32 dask.array<chunksize=(1, 1081, 1440), meta=np.ndarray>
#     thetao     (time, lev, yh, xh) float32 dask.array<chunksize=(1, 19, 1080, 1440), meta=np.ndarray>
#     time_bnds  (time, nv) float32 dask.array<chunksize=(1, 2), meta=np.ndarray>
#     uo         (time, lev, yh, xq) float32 dask.array<chunksize=(1, 19, 1080, 1441), meta=np.ndarray>
#     vo         (time, lev, yq, xh) float32 dask.array<chunksize=(1, 19, 1081, 1440), meta=np.ndarray>
#     zos        (time, yh, xh) float32 dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
# Attributes:
#     title:             OM4p25_5daily_cycle1
#     associated_files:  areacello: 19580101.ocean_static.nc
#     grid_type:         regular
#     grid_tile:         N/A

# %%
ds_raw
# Out:
# <xarray.Dataset>
# Dimensions:     (xh: 1440, yh: 1080, time: 4745, nv: 2, z_l: 19, z_i: 20,
#                  xq: 1441, yq: 1081)
# Coordinates:
#   * xh          (xh) float64 -299.7 -299.5 -299.2 -299.0 ... 59.53 59.78 60.03
#   * yh          (yh) float64 -80.39 -80.31 -80.23 -80.15 ... 89.73 89.84 89.95
#   * time        (time) object 1958-01-03 12:00:00 ... 2022-12-29 12:00:00
#   * nv          (nv) float64 1.0 2.0
#   * z_l         (z_l) float64 2.5 10.0 22.5 40.0 ... 3.1e+03 4e+03 5e+03 6e+03
#   * z_i         (z_i) float64 0.0 5.0 15.0 30.0 ... 4.5e+03 5.5e+03 6.5e+03
#   * xq          (xq) float64 -299.8 -299.6 -299.3 -299.1 ... 59.66 59.91 60.16
#   * yq          (yq) float64 -80.43 -80.35 -80.27 -80.19 ... 89.78 89.89 90.0
# Data variables: (12/23)
#     zos         (time, yh, xh) float64 dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     thetao      (time, z_l, yh, xh) float32 dask.array<chunksize=(1, 19, 1080, 1440), meta=np.ndarray>
#     so          (time, z_l, yh, xh) float32 dask.array<chunksize=(1, 19, 1080, 1440), meta=np.ndarray>
#     uo          (time, z_l, yh, xq) float64 dask.array<chunksize=(1, 19, 1080, 1441), meta=np.ndarray>
#     vo          (time, z_l, yq, xh) float64 dask.array<chunksize=(1, 19, 1081, 1440), meta=np.ndarray>
#     prlq        (time, yh, xh) float64 dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     ...          ...
#     tauvo       (time, yq, xh) float64 dask.array<chunksize=(1, 1081, 1440), meta=np.ndarray>
#     ustar       (time, yh, xh) float64 dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     average_T1  (time) object dask.array<chunksize=(1,), meta=np.ndarray>
#     average_T2  (time) object dask.array<chunksize=(1,), meta=np.ndarray>
#     average_DT  (time) timedelta64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#     time_bnds   (time, nv) object dask.array<chunksize=(1, 2), meta=np.ndarray>
# Attributes:
#     title:             OM4p25_5daily_cycle1
#     associated_files:  areacello: 19580101.ocean_static.nc
#     grid_type:         regular
#     grid_tile:         N/A

# %% [markdown]
# This dataset still has staggered grid variables, and we cannot apply the nan-consistency logic as is.
# Instead we compare all variables on each grid location seperately.

# %%
ds_u = ds[[v for v in ds.data_vars if set(['xq', 'yh']).issubset(set(ds[v].dims))]]
ds_v = ds[[v for v in ds.data_vars if set(['xh', 'yq']).issubset(set(ds[v].dims))]]
ds_t = ds[[v for v in ds.data_vars if set(['xh', 'yh']).issubset(set(ds[v].dims))]]

# %%
from dask.diagnostics import ProgressBar
test_dict = {}
for (test_ds, id) in [(ds_t, 'tracer'), (ds_u, 'u'), (ds_v, 'v')]:
    with ProgressBar():
        try:
            test_nan_consistency(test_ds)
            test_dict[id] = 'passed'
            print(id, 'passed')
        except Exception as e:
            test_dict = str(e)
            print(id, f'failed with {e}')
# Out:
# [########################################] | 100% Completed | 50m 17s
# [########################################] | 100% Completed | 64m 3ss
# tracer passed
# [########################################] | 100% Completed | 29m 46s
# [########################################] | 100% Completed | 31m 22s
# u passed
# [########################################] | 100% Completed | 32m 55s
# [########################################] | 100% Completed | 32m 14s
# v passed

# %%
test_dict
# Out:
# {'tracer': 'passed', 'u': 'passed', 'v': 'passed'}
